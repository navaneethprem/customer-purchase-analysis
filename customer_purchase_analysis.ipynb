# %% [markdown]
# <a href="https://colab.research.google.com/github/navaneethprem/customer-purchase-analysis/blob/main/customer_purchase_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/Customer_Purchase_Data.csv')

df.head()
# Out:
#   InvoiceNo Customer        Date     Item  Quantity  Price  Total
# 0    INV001    Alice  2024-01-05  T-Shirt         2    300    600
# 1    INV002     John  2024-01-08    Jeans         1   1200   1200
# 2    INV003    Alice  2024-02-01    Shoes         1   2000   2000
# 3    INV004      Bob  2024-02-10      Hat         3    150    450
# 4    INV005    Emily  2024-03-15  T-Shirt         2    300    600

# %%
df['Date']=pd.to_datetime(df['Date'])
monthly_sales['Month'] = monthly_sales['Month'].astype(str)
df.head()
# Out:
#   InvoiceNo Customer       Date     Item  Quantity  Price  Total    Month
# 0    INV001    Alice 2024-01-05  T-Shirt         2    300    600  2024-01
# 1    INV002     John 2024-01-08    Jeans         1   1200   1200  2024-01
# 2    INV003    Alice 2024-02-01    Shoes         1   2000   2000  2024-02
# 3    INV004      Bob 2024-02-10      Hat         3    150    450  2024-02
# 4    INV005    Emily 2024-03-15  T-Shirt         2    300    600  2024-03

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='whitegrid')

# %%
monthly_sales=df.groupby('Month')['Total'].sum().reset_index()

# %%
plt.figure(figsize=(8,5))

# %%
sns.lineplot(x='Month',y='Total',data=monthly_sales,marker='o')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()
